# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('student-mat.csv', sep=';')

# Display the first few rows of the DataFrame
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df['failures'].value_counts()
# Out:
# failures
# 0    312
# 1     50
# 2     17
# 3     16
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# F    208
# M    187
# Name: count, dtype: int64

# %%
import json
json_data = json.loads(df.to_json(orient='records'))
json_data[:5]
# Out:
# [{'school': 'GP',
#   'sex': 'F',
#   'age': 18,
#   'address': 'U',
#   'famsize': 'GT3',
#   'Pstatus': 'A',
#   'Medu': 4,
#   'Fedu': 4,
#   'Mjob': 'at_home',
#   'Fjob': 'teacher',
#   'reason': 'course',
#   'guardian': 'mother',
#   'traveltime': 2,
#   'studytime': 2,
#   'failures': 0,
#   'schoolsup': 'yes',
#   'famsup': 'no',
#   'paid': 'no',
#   'activities': 'no',
#   'nursery': 'yes',
#   'higher': 'yes',
#   'internet': 'no',
#   'romantic': 'no',
#   'famrel': 4,
#   'freetime': 3,
#   'goout': 4,
#   'Dalc': 1,
#   'Walc': 1,
#   'health': 3,
#   'absences': 6,
#   'G1': 5,
#   'G2': 6,
#   'G3': 6},
#  {'school': 'GP',
#   'sex': 'F',
#   'age': 17,
#   'address': 'U',
#   'famsize': 'GT3',
#   'Pstatus': 'T',
#   'Medu': 1,
#   'Fedu': 1,
#   'Mjob': 'at_home',
#   'Fjob': 'other',
#   'reason': 'course',
#   'guardian': 'father',
#   'traveltime': 1,
#   'studytime': 2,
#   'failures': 0,
#   'schoolsup': 'no',
#   'famsup': 'yes',
#   'paid': 'no',
# ...

# %%
import json

# Print the body JSON object
# Read the veracity-config.json file
with open('veracity-config.json') as file:
    config = json.load(file)

# Create the body JSON object
body_json = {
    'data': json_data,
    'config': config,
}

# %%
import requests

url = 'http://localhost:3000/checks'
headers = {'Content-Type': 'application/json'}
response = requests.post(url, json=body_json, headers=headers)

print(response.status_code)
print(response.text)  # print raw response text
# Out:
# 200
# {"processId":"39b520f1-b0c1-4571-90a4-2b861dcd3b77"}

# %%
import json
url = 'http://localhost:3000/checks/:id'

if response.status_code == 200:
    process_id = json.loads(response.text)['processId']
    print(process_id)
    url_with_id = url.replace(':id', process_id)
    response_with_id = requests.get(url_with_id)
    print(response_with_id.status_code)
    pretty_response = json.dumps(json.loads(response_with_id.text), indent=4)
    print(pretty_response)
else:
    print("Error: Status code is not 200")
# Out:
# 39b520f1-b0c1-4571-90a4-2b861dcd3b77
# 200
# {
#     "status": "Done",
#     "result": {
#         "problems": [
#             {
#                 "target": "/0/failures",
#                 "message": "must be >= 1"
#             },
#             {
#                 "target": "G3 mean",
#                 "message": "'< 3' not satisfied"
#             }
#         ],
#         "time": 35
#     }
# }
